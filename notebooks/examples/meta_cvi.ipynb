# %%
import pandas as pd
import cupy as cp
from gamac.pipeline.cvi_predictor import CVIPredictor

df = pd.read_csv(f'../../gamac/tests/data/character-mlle2/gen.csv', header=None)
data =  cp.asarray(df.values, dtype=cp.float32, order='C')

cvi_predictor = CVIPredictor()
result = cvi_predictor.run(data)

print(result)
# Out:
# === CVI prediction iteration 1/40 ====
# === CVI prediction iteration 2/40 ====
# === CVI prediction iteration 3/40 ====
# === CVI prediction iteration 4/40 ====
# === CVI prediction iteration 5/40 ====
# === CVI prediction iteration 6/40 ====
# === CVI prediction iteration 7/40 ====
# === CVI prediction iteration 8/40 ====
# === CVI prediction iteration 9/40 ====
# === CVI prediction iteration 10/40 ====
# === CVI prediction iteration 11/40 ====
# === CVI prediction iteration 12/40 ====
# === CVI prediction iteration 13/40 ====
# === CVI prediction iteration 14/40 ====
# === CVI prediction iteration 15/40 ====
# === CVI prediction iteration 16/40 ====
# === CVI prediction iteration 17/40 ====
# === CVI prediction iteration 18/40 ====
# === CVI prediction iteration 19/40 ====
# === CVI prediction iteration 20/40 ====
# === CVI prediction iteration 21/40 ====
# === CVI prediction iteration 22/40 ====
# === CVI prediction iteration 23/40 ====
# === CVI prediction iteration 24/40 ====
# ...
